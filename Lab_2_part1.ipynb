# %% [markdown]
# <a href="https://colab.research.google.com/github/Haseebtanvir079/Advanced-DataScience/blob/main/Lab_2_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CMP7161
#
# # Objectives
# In this lab you will:
# * Apply univariate data analysis techniques to better understand how individual variables / attributes are distributed
# *	Apply basic visualisation techniques to better identify the relationships between variables
# * Define the nominal / categorical variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # Seaborn is a useful library for Data Visualisation
from scipy.stats import skewnorm

# %% [markdown]
# [Read more on Colab Autocomplete](https://saturncloud.io/blog/is-it-possible-to-have-autocomplete-in-a-notebook-in-google-colab/)

# %%
# !pip install jupyter_contrib_nbextensions && jupyter contrib nbextension install --user
# Out:
# Collecting jupyter_contrib_nbextensions
#   Downloading jupyter_contrib_nbextensions-0.7.0.tar.gz (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 67.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: ipython_genutils in /usr/local/lib/python3.12/dist-packages (from jupyter_contrib_nbextensions) (0.2.0)
# Collecting jupyter_contrib_core>=0.3.3 (from jupyter_contrib_nbextensions)
#   Downloading jupyter_contrib_core-0.4.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jupyter_core in /usr/local/lib/python3.12/dist-packages (from jupyter_contrib_nbextensions) (5.9.1)
# Collecting jupyter_highlight_selected_word>=0.1.1 (from jupyter_contrib_nbextensions)
#   Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl.metadata (730 bytes)
# Collecting jupyter_nbextensions_configurator>=0.4.0 (from jupyter_contrib_nbextensions)
#   Downloading jupyter_nbextensions_configurator-0.6.4-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: nbconvert>=6.0 in /usr/local/lib/python3.12/dist-packages (from jupyter_contrib_nbextensions) (7.16.6)
# Requirement already satisfied: notebook>=6.0 in /usr/local/lib/python3.12/dist-packages (from jupyter_contrib_nbextensions) (6.5.7)
# Requirement already satisfied: tornado in /usr/local/lib/python3.12/dist-packages (from jupyter_contrib_nbextensions) (6.5.1)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/lib/python3.12/dist-packages (from jupyter_contrib_nbextensions) (5.7.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from jupyter_contrib_nbextensions) (6.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions) (75.2.0)
# Requirement already satisfied: jupyter-server in /usr/local/lib/python3.12/dist-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2.14.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (6.0.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (0.10.4)
# Requirement already satisfied: nbformat>=5.7 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (5.10.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (25.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions) (2.19.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter_core->jupyter_contrib_nbextensions) (4.5.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (26.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (25.1.0)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (7.4.9)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (6.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (0.24.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=6.0->jupyter_contrib_nbextensions) (1.3.3)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.0->jupyter_contrib_nbextensions) (1.4.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client<8,>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client<8,>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (2.9.0.post0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.26.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (25.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions) (4.15.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (5.9.5)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.12.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.11)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert>=6.0->jupyter_contrib_nbextensions) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (0.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->jupyter-client<8,>=5.3.4->notebook>=6.0->jupyter_contrib_nbextensions) (1.17.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions) (3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.8.5)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (25.10.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions) (0.5.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (1.4.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server->jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions) (2025.3)
# Downloading jupyter_highlight_selected_word-0.2.0-py2.py3-none-any.whl (11 kB)
# Downloading jupyter_nbextensions_configurator-0.6.4-py2.py3-none-any.whl (466 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.9/466.9 kB 29.4 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.2 MB/s eta 0:00:00
# Building wheels for collected packages: jupyter_contrib_nbextensions, jupyter_contrib_core
#   Building wheel for jupyter_contrib_nbextensions (setup.py) ... done
#   Created wheel for jupyter_contrib_nbextensions: filename=jupyter_contrib_nbextensions-0.7.0-py2.py3-none-any.whl size=23428769 sha256=a6b8689afe5ff51853d4711ac1647a1ce94c12a4291cb1dde534425638c810d5
#   Stored in directory: /root/.cache/pip/wheels/4d/e4/20/dd16cdbbddcfe309a4559ea16adfa75fa5c554cfd076f9dae8
#   Building wheel for jupyter_contrib_core (setup.py) ... done
#   Created wheel for jupyter_contrib_core: filename=jupyter_contrib_core-0.4.2-py2.py3-none-any.whl size=17477 sha256=a932efcfa1e3c3a3022c468abb101e03d1b0fe205a0e1449099eccd62701dd82
#   Stored in directory: /root/.cache/pip/wheels/32/f9/af/259a6f50f8b89d972aa81e31808a0af14e8bfc6867fb16ed07
# Successfully built jupyter_contrib_nbextensions jupyter_contrib_core
# Installing collected packages: jupyter_highlight_selected_word, jedi, jupyter_contrib_core, jupyter_nbextensions_configurator, jupyter_contrib_nbextensions
# Successfully installed jedi-0.19.2 jupyter_contrib_core-0.4.2 jupyter_contrib_nbextensions-0.7.0 jupyter_highlight_selected_word-0.2.0 jupyter_nbextensions_configurator-0.6.4
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# [I 11:13:03 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 11:13:03 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/autosavetime -> autosavetime
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/autosavetime/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/autosavetime/README.md -> /root/.local/share/jupyter/nbextensions/autosavetime/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/autosavetime/icon.png -> /root/.local/share/jupyter/nbextensions/autosavetime/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/autosavetime/autosavetime.yaml -> /root/.local/share/jupyter/nbextensions/autosavetime/autosavetime.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/autosavetime/main.js -> /root/.local/share/jupyter/nbextensions/autosavetime/main.js
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings -> collapsible_headings
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/collapsible_headings/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/icon.png -> /root/.local/share/jupyter/nbextensions/collapsible_headings/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/main.css -> /root/.local/share/jupyter/nbextensions/collapsible_headings/main.css
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/main.js -> /root/.local/share/jupyter/nbextensions/collapsible_headings/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/screenshot.png -> /root/.local/share/jupyter/nbextensions/collapsible_headings/screenshot.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/readme.md -> /root/.local/share/jupyter/nbextensions/collapsible_headings/readme.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/collapsible_headings/collapsible_headings.yaml -> /root/.local/share/jupyter/nbextensions/collapsible_headings/collapsible_headings.yaml
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/rubberband -> rubberband
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/rubberband/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/icon.png -> /root/.local/share/jupyter/nbextensions/rubberband/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/main.css -> /root/.local/share/jupyter/nbextensions/rubberband/main.css
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/rubberband.yaml -> /root/.local/share/jupyter/nbextensions/rubberband/rubberband.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/main.js -> /root/.local/share/jupyter/nbextensions/rubberband/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/rubberband/readme.md -> /root/.local/share/jupyter/nbextensions/rubberband/readme.md
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap -> select_keymap
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/select_keymap/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap/README.md -> /root/.local/share/jupyter/nbextensions/select_keymap/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap/main.js -> /root/.local/share/jupyter/nbextensions/select_keymap/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap/select_keymap.yaml -> /root/.local/share/jupyter/nbextensions/select_keymap/select_keymap.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/select_keymap/select_keymap.png -> /root/.local/share/jupyter/nbextensions/select_keymap/select_keymap.png
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/comment-uncomment -> comment-uncomment
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/comment-uncomment/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/comment-uncomment/icon.png -> /root/.local/share/jupyter/nbextensions/comment-uncomment/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/comment-uncomment/main.js -> /root/.local/share/jupyter/nbextensions/comment-uncomment/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/comment-uncomment/readme.md -> /root/.local/share/jupyter/nbextensions/comment-uncomment/readme.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/comment-uncomment/comment-uncomment.yaml -> /root/.local/share/jupyter/nbextensions/comment-uncomment/comment-uncomment.yaml
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/load_tex_macros -> load_tex_macros
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/load_tex_macros/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/load_tex_macros/icon.png -> /root/.local/share/jupyter/nbextensions/load_tex_macros/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/load_tex_macros/main.js -> /root/.local/share/jupyter/nbextensions/load_tex_macros/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/load_tex_macros/readme.md -> /root/.local/share/jupyter/nbextensions/load_tex_macros/readme.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/load_tex_macros/load_tex_macros.yaml -> /root/.local/share/jupyter/nbextensions/load_tex_macros/load_tex_macros.yaml
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/code_prettify/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/code_prettify.js -> /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/README_2to3.md -> /root/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/README.md -> /root/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/2to3.yaml -> /root/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/isort.js -> /root/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/README_autopep8.md -> /root/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/demo-py.gif -> /root/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/code_prettify.yaml -> /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/demo-R.gif -> /root/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/isort.yaml -> /root/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/demo_2to3.gif -> /root/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/README_code_prettify.md -> /root/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/kernel_exec_on_cell.js -> /root/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/2to3.js -> /root/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/autopep8.js -> /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/README_isort.md -> /root/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/autopep8.yaml -> /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify/demo-jv.gif -> /root/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/code_prettify -> code_prettify
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_2to3.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_autopep8.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-py.gif
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/code_prettify.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-R.gif
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/isort.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo_2to3.gif
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_code_prettify.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/kernel_exec_on_cell.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/2to3.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/README_isort.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/autopep8.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/code_prettify/demo-jv.gif
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate -> nbTranslate
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/nbTranslate/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/demo1.gif -> /root/.local/share/jupyter/nbextensions/nbTranslate/demo1.gif
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/README.md -> /root/.local/share/jupyter/nbextensions/nbTranslate/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/languages.js -> /root/.local/share/jupyter/nbextensions/nbTranslate/languages.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/main.js -> /root/.local/share/jupyter/nbextensions/nbTranslate/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/mutils.js -> /root/.local/share/jupyter/nbextensions/nbTranslate/mutils.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/nbTranslate.js -> /root/.local/share/jupyter/nbextensions/nbTranslate/nbTranslate.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/nbTranslate.yaml -> /root/.local/share/jupyter/nbextensions/nbTranslate/nbTranslate.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/nbTranslate/demo2.gif -> /root/.local/share/jupyter/nbextensions/nbTranslate/demo2.gif
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor -> keyboard_shortcut_editor
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/README.md -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/icon.png -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_comma.png -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_comma.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_undefined_key.png -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_undefined_key.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_reset_disabled.png -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_reset_disabled.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_success.png -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_success.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_blank.png -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_shortcut_editor_blank.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_add_new_link.png -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_add_new_link.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/main.css -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/main.css
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/main.js -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_add_new_select_action.png -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_add_new_select_action.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/kse_components.js -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/kse_components.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_dropdown.png -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_dropdown.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_conflict.png -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_conflict.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/quickhelp_shim.js -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/quickhelp_shim.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/readme_menu_item.png -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/readme_menu_item.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/keyboard_shortcut_editor/keyboard_shortcut_editor.yaml -> /root/.local/share/jupyter/nbextensions/keyboard_shortcut_editor/keyboard_shortcut_editor.yaml
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/hide_input_all -> hide_input_all
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/hide_input_all/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/hide_input_all/icon.png -> /root/.local/share/jupyter/nbextensions/hide_input_all/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/hide_input_all/hide_input_all.yaml -> /root/.local/share/jupyter/nbextensions/hide_input_all/hide_input_all.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/hide_input_all/main.js -> /root/.local/share/jupyter/nbextensions/hide_input_all/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/hide_input_all/hide_input_all_show.png -> /root/.local/share/jupyter/nbextensions/hide_input_all/hide_input_all_show.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/hide_input_all/readme.md -> /root/.local/share/jupyter/nbextensions/hide_input_all/readme.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/hide_input_all/hide_input_all_hide.png -> /root/.local/share/jupyter/nbextensions/hide_input_all/hide_input_all_hide.png
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/contrib_nbextensions_help_item -> contrib_nbextensions_help_item
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/contrib_nbextensions_help_item/README.md -> /root/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/contrib_nbextensions_help_item/contrib_nbextensions_help_item.yaml -> /root/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/contrib_nbextensions_help_item.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/contrib_nbextensions_help_item/main.js -> /root/.local/share/jupyter/nbextensions/contrib_nbextensions_help_item/main.js
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/addbefore -> addbefore
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/addbefore/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/addbefore/icon.png -> /root/.local/share/jupyter/nbextensions/addbefore/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/addbefore/main.js -> /root/.local/share/jupyter/nbextensions/addbefore/main.js
# ...
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/readme.md -> /root/.local/share/jupyter/nbextensions/snippets_menu/readme.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/config.yaml -> /root/.local/share/jupyter/nbextensions/snippets_menu/config.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/numpy.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/scipy_special.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy_special.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/numba.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numba.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/matplotlib.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/matplotlib.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/sympy.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/h5py.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/h5py.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/astropy.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/astropy.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/python.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/python.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/numpy_ufuncs.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy_ufuncs.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/sympy_functions.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy_functions.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/sympy_assumptions.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/sympy_assumptions.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/numpy_polynomial.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/numpy_polynomial.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/scipy_constants.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy_constants.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/python_regex.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/python_regex.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/pandas.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/pandas.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/snippets_menu/snippets_submenus_python/scipy.js -> /root/.local/share/jupyter/nbextensions/snippets_menu/snippets_submenus_python/scipy.js
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/ruler -> ruler
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/ruler/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/ruler/edit.js -> /root/.local/share/jupyter/nbextensions/ruler/edit.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/ruler/icon.png -> /root/.local/share/jupyter/nbextensions/ruler/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/ruler/main.js -> /root/.local/share/jupyter/nbextensions/ruler/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/ruler/ruler_editor.yaml -> /root/.local/share/jupyter/nbextensions/ruler/ruler_editor.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/ruler/readme.md -> /root/.local/share/jupyter/nbextensions/ruler/readme.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/ruler/ruler.yaml -> /root/.local/share/jupyter/nbextensions/ruler/ruler.yaml
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/ruler -> ruler
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/edit.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/ruler_editor.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/readme.md
# [I 11:13:03 InstallContribNbextensionsApp] Up to date: /root/.local/share/jupyter/nbextensions/ruler/ruler.yaml
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/exercise -> exercise
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/exercise/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/exercise/history.md -> /root/.local/share/jupyter/nbextensions/exercise/history.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/exercise/exercise.yaml -> /root/.local/share/jupyter/nbextensions/exercise/exercise.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/exercise/icon.png -> /root/.local/share/jupyter/nbextensions/exercise/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/exercise/main.css -> /root/.local/share/jupyter/nbextensions/exercise/main.css
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/exercise/main.js -> /root/.local/share/jupyter/nbextensions/exercise/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/exercise/image.gif -> /root/.local/share/jupyter/nbextensions/exercise/image.gif
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/exercise/readme.md -> /root/.local/share/jupyter/nbextensions/exercise/readme.md
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/autoscroll -> autoscroll
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/autoscroll/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/autoscroll/README.md -> /root/.local/share/jupyter/nbextensions/autoscroll/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/autoscroll/icon.png -> /root/.local/share/jupyter/nbextensions/autoscroll/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/autoscroll/main.js -> /root/.local/share/jupyter/nbextensions/autoscroll/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/autoscroll/autoscroll.yaml -> /root/.local/share/jupyter/nbextensions/autoscroll/autoscroll.yaml
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector -> varInspector
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/varInspector/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector/varInspector.yaml -> /root/.local/share/jupyter/nbextensions/varInspector/varInspector.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector/var_list.py -> /root/.local/share/jupyter/nbextensions/varInspector/var_list.py
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector/tablesorter_LICENSE.txt -> /root/.local/share/jupyter/nbextensions/varInspector/tablesorter_LICENSE.txt
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector/README.md -> /root/.local/share/jupyter/nbextensions/varInspector/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector/icon.png -> /root/.local/share/jupyter/nbextensions/varInspector/icon.png
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector/main.css -> /root/.local/share/jupyter/nbextensions/varInspector/main.css
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector/jquery.tablesorter.min.js -> /root/.local/share/jupyter/nbextensions/varInspector/jquery.tablesorter.min.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector/main.js -> /root/.local/share/jupyter/nbextensions/varInspector/main.js
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector/demo.gif -> /root/.local/share/jupyter/nbextensions/varInspector/demo.gif
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector/var_list.r -> /root/.local/share/jupyter/nbextensions/varInspector/var_list.r
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/varInspector/__pycache__
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_contrib_nbextensions/nbextensions/varInspector/__pycache__/var_list.cpython-312.pyc -> /root/.local/share/jupyter/nbextensions/varInspector/__pycache__/var_list.cpython-312.pyc
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing /usr/local/lib/python3.12/dist-packages/jupyter_highlight_selected_word/static/highlight_selected_word -> highlight_selected_word
# [I 11:13:03 InstallContribNbextensionsApp] Making directory: /root/.local/share/jupyter/nbextensions/highlight_selected_word/
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_highlight_selected_word/static/highlight_selected_word/README.md -> /root/.local/share/jupyter/nbextensions/highlight_selected_word/README.md
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_highlight_selected_word/static/highlight_selected_word/configurator.yaml -> /root/.local/share/jupyter/nbextensions/highlight_selected_word/configurator.yaml
# [I 11:13:03 InstallContribNbextensionsApp] Copying: /usr/local/lib/python3.12/dist-packages/jupyter_highlight_selected_word/static/highlight_selected_word/main.js -> /root/.local/share/jupyter/nbextensions/highlight_selected_word/main.js
# [I 11:13:03 InstallContribNbextensionsApp] - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions items to config in /root/.jupyter
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /root/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.6.4 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
# [I 11:13:03 InstallContribNbextensionsApp] Enabling notebook extension contrib_nbextensions_help_item/main...
# [I 11:13:03 InstallContribNbextensionsApp]       - Validating: OK
# [I 11:13:03 InstallContribNbextensionsApp] - Editing config: /root/.jupyter/jupyter_nbconvert_config.json
# [I 11:13:03 InstallContribNbextensionsApp] --  Configuring nbconvert template path
# [I 11:13:03 InstallContribNbextensionsApp] --  Configuring nbconvert preprocessors
# [I 11:13:03 InstallContribNbextensionsApp] - Writing config: /root/.jupyter/jupyter_nbconvert_config.json
# [I 11:13:03 InstallContribNbextensionsApp] --  Writing updated config file /root/.jupyter/jupyter_nbconvert_config.json

# %% [markdown]
# [Install Skimpy library](https://pypi.org/project/skimpy/)

# %%
# !pip install skimpy  #Uncomment the cell to install Skimpy library
# Out:
# Requirement already satisfied: skimpy in /usr/local/lib/python3.12/dist-packages (0.0.20)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.12/dist-packages (from skimpy) (8.3.1)
# Requirement already satisfied: ipykernel>=6.29.5 in /usr/local/lib/python3.12/dist-packages (from skimpy) (7.1.0)
# Requirement already satisfied: numpy>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from skimpy) (2.0.2)
# Requirement already satisfied: pandas-stubs>=2.2.2.240807 in /usr/local/lib/python3.12/dist-packages (from skimpy) (2.2.2.240909)
# Requirement already satisfied: pandas>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from skimpy) (3.0.0)
# Requirement already satisfied: polars>=1.17.1 in /usr/local/lib/python3.12/dist-packages (from skimpy) (1.31.0)
# Requirement already satisfied: pygments>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from skimpy) (2.19.2)
# Requirement already satisfied: rich>=13.9.4 in /usr/local/lib/python3.12/dist-packages (from skimpy) (13.9.4)
# Requirement already satisfied: typeguard>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from skimpy) (4.4.4)
# Requirement already satisfied: pyarrow>=17.0.0 in /usr/local/lib/python3.12/dist-packages (from skimpy) (18.1.0)
# Requirement already satisfied: pydoclint>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from skimpy) (0.8.3)
# Requirement already satisfied: duckdb>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from skimpy) (1.3.2)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (7.34.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (1.6.0)
# Requirement already satisfied: packaging>=22 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (25.0)
# Requirement already satisfied: psutil>=5.7 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (5.9.5)
# Requirement already satisfied: pyzmq>=25 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (26.2.1)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=6.29.5->skimpy) (5.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->skimpy) (2.9.0.post0)
# Requirement already satisfied: types-pytz>=2022.1.1 in /usr/local/lib/python3.12/dist-packages (from pandas-stubs>=2.2.2.240807->skimpy) (2025.2.0.20251108)
# Requirement already satisfied: docstring_parser_fork>=0.0.12 in /usr/local/lib/python3.12/dist-packages (from pydoclint>=0.6.0->skimpy) (0.0.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.9.4->skimpy) (4.0.0)
# Requirement already satisfied: typing_extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from typeguard>=4.4.1->skimpy) (4.15.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (4.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=6.29.5->skimpy) (4.5.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->skimpy) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->skimpy) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=6.29.5->skimpy) (0.5.0)

# %% [markdown]
# # Data sets

# %% [markdown]
# Before going any further please make sure you have created a CMP7161/datasets folder in Colab and uploaded the following files into it:
#
#
#   * This can be found within the ["datasets"](https://moodle.bcu.ac.uk/mod/folder/view.php?id=8217579) folder on Moodle

# %%
# Downloaded from UCI Machine learning repository
# https://archive.ics.uci.edu/ml/datasets/iris
# "Data Folder" -> iris.data
# "Data Folder" -> iris.names will give us some more data on the attributes

df_iris = pd.read_csv('datasets/iris.csv', names=['SepalLength','SepalWidth','PetalLength','PetalWidth','Species'])
df_iris.head()
# Out:
#   SepalLength SepalWidth PetalLength PetalWidth Species
# 0        Type         PW          PL         SW      SL
# 1           0          2          14         33      50
# 2           1         24          56         31      67
# 3           1         23          51         31      69
# 4           0          2          10         36      46

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# We can use the describe() method to obtain valuable statistical information about data within our data frame. When dealing with numeric values it provides attributes such as:
#
#
# *   A count of the amount of items for that variable / column
# *   The [mean average](https://simple.wikipedia.org/wiki/Mean) for that variable / column
# *   The [standard deviation](https://simple.wikipedia.org/wiki/Standard_deviation) of that column
# *   The minimum value found within that variable / column
# *   The [percentile values](https://simple.wikipedia.org/wiki/Percentile) for that variable / column (25%, 50%, 75%). For more information on percentiles, see [here](https://www.w3schools.com/python/python_ml_percentile.asp)
# *   The maximum value found within that variable / column

# %%
# Note how there is no description summary for the Species column?
# Why do you think this is?
df_iris.describe()
# Out:
#        SepalLength SepalWidth PetalLength PetalWidth Species
# count          151        151         151        151     151
# unique           4         23          44         24      36
# top              0          2          14         30      50
# freq            50         29          13         26       9

# %%
# We can include all columns by using the optional argument include with the value 'all'
df_iris.describe(include='all')
# Out:
#        SepalLength SepalWidth PetalLength PetalWidth Species
# count          151        151         151        151     151
# unique           4         23          44         24      36
# top              0          2          14         30      50
# freq            50         29          13         26       9

# %%
df_contact_lenses = pd.read_csv('datasets/contact-lenses.csv')
df_contact_lenses.head(10)
# Out:
#               age spectacle_prescrip astigmatism tear_prod_rate contact_lenses
# 0           young              myope          no        reduced           none
# 1           young              myope          no         normal           soft
# 2           young              myope         yes        reduced           none
# 3           young              myope         yes         normal           hard
# 4           young       hypermetrope          no        reduced           none
# 5           young       hypermetrope          no         normal           soft
# 6           young       hypermetrope         yes        reduced           none
# 7           young       hypermetrope         yes         normal           hard
# 8  pre-presbyopic              myope          no        reduced           none
# 9  pre-presbyopic              myope          no         normal           soft

# %%
# Original download from https://archive.ics.uci.edu/ml/datasets/wine
df_wine = pd.read_csv('datasets/wine.csv')
df_wine.head()
# Out:
#    Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# 0           1            7.0              0.27         0.36            20.7
# 1           2            6.3              0.30         0.34             1.6
# 2           3            8.1              0.28         0.40             6.9
# 3           4            7.2              0.23         0.32             8.5
# 4           5            7.2              0.23         0.32             8.5
#
#    chlorides  free.sulfur.dioxide  total.sulfur.dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality   type quality_ind
# 0       0.45      8.8        6  White         Low
# 1       0.49      9.5        6  White         Low
# 2       0.44     10.1        6  White         Low
# 3       0.40      9.9        6  White         Low
# 4       0.40      9.9        6  White         Low

# %%
# Derived from the same dataset as: https://data.world/nrippner/titanic-disaster-dataset
df_titanic = pd.read_csv('datasets/titanic.csv')
df_titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
df_airbnb = pd.read_csv('datasets/airbnb.csv')
df_airbnb.head()
# Out:
#            ID  DATE_DIFF  GENDER   AGE COUNTRY
# 0  lsw9q7uk0j          3  FEMALE  46.0      US
# 1  0d01nltbrs         10  FEMALE  47.0      US
# 2  a1vcnhxeij        206  FEMALE  50.0      US
# 3  yuuqmid2rp          2  FEMALE  36.0      US
# 4  v4d5rl22px          1  FEMALE  33.0      CA

# %%
# https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database
# Note that because the dataset has no headers in the file,
# we have to provide the column names manually
df_diabetes = pd.read_csv('datasets/diabetes.csv',
                          names=['Pregnancies','Glucose','BloodPressure',
                                 'SkinThickness','Insulin','BMI',
                                 'DiabetesPedigreeFunction','Age','Outcome'])
df_diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
#
#    DiabetesPedigreeFunction  Age Outcome
# 0  DiabetesPedigreeFunction  Age       y
# 1                     0.627   50       1
# 2                     0.351   31       0
# 3                     0.672   32       1
# 4                     0.167   21       0

# %%
df_heart = pd.read_csv('Heart.csv')
df_heart.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
df_students = pd.read_csv('StudentsPerformance.csv')
df_students.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#https://archive.ics.uci.edu/ml/datasets/Occupancy+Detection+

# The occupancy data set comes split up into three different files
# datatraining.txt
# datatest.txt
# datatest2.txt
# We can concatenate (join) them together by:
# mapping the read_csv function over each dataframe's file path
# giving us 3 different data frames
# We can then use pd.concat to combine those dataframe together into one
df_occupancy = pd.concat(map(pd.read_csv,
                    ['testfolder/datatraining.txt',
                     'testfolder/datatest.txt',
                     'testfolder/datatest2.txt']))
df_occupancy.head()
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 1  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 3  2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 4  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 5  2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1

# %% [markdown]
# # Skimpy - Another Way to Summarize Pandas Dataframes.
#
# Skimpy is a small python package that shows some extended summary results for a dataset.

# %%
#!pip install skimpy

# %%
from skimpy import skim
import pandas as pd

# %%
df = pd.read_csv('datasets/wine.csv')

# %%
#  skimpy generates more matrices and histograms about the dataset.
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 6497   │ │ float64     │ 11    │                                                          │
# │ │ Number of columns │ 15     │ │ int64       │ 2     │                                                          │
# │ └───────────────────┴────────┘ │ string      │ 2     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━┓  │
# │ ┃ column                ┃ NA ┃ NA % ┃ mean    ┃ sd       ┃ p0     ┃ p25    ┃ p50    ┃ p75   ┃ p100  ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━┩  │
# │ │      Unnamed: 0       │  0 │    0 │    3249 │     1876 │      1 │   1625 │   3249 │  4873 │  6497 │ ██████ │  │
# │ │     fixed.acidity     │  0 │    0 │   7.215 │    1.296 │    3.8 │    6.4 │      7 │   7.7 │  15.9 │  ▁█▂   │  │
# │ │   volatile.acidity    │  0 │    0 │  0.3397 │   0.1646 │   0.08 │   0.23 │   0.29 │   0.4 │  1.58 │  █▄▁   │  │
# │ │      citric.acid      │  0 │    0 │  0.3186 │   0.1453 │      0 │   0.25 │   0.31 │  0.39 │  1.66 │  ▅█▁   │  │
# │ │    residual.sugar     │  0 │    0 │   5.443 │    4.758 │    0.6 │    1.8 │      3 │   8.1 │  65.8 │   █▁   │  │
# │ │       chlorides       │  0 │    0 │ 0.05603 │  0.03503 │  0.009 │  0.038 │  0.047 │ 0.065 │ 0.611 │   █    │  │
# │ │  free.sulfur.dioxide  │  0 │    0 │   30.53 │    17.75 │      1 │     17 │     29 │    41 │   289 │   █▁   │  │
# │ │ total.sulfur.dioxide  │  0 │    0 │   115.7 │    56.52 │      6 │     77 │    118 │   156 │   440 │  ▄█▄   │  │
# │ │        density        │  0 │    0 │  0.9947 │ 0.002999 │ 0.9871 │ 0.9923 │ 0.9949 │ 0.997 │ 1.039 │   █▅   │  │
# │ │          pH           │  0 │    0 │   3.219 │   0.1608 │   2.72 │   3.11 │   3.21 │  3.32 │  4.01 │   ▅█▃  │  │
# │ │       sulphates       │  0 │    0 │  0.5313 │   0.1488 │   0.22 │   0.43 │   0.51 │   0.6 │     2 │  █▇▁   │  │
# │ │        alcohol        │  0 │    0 │   10.49 │    1.193 │      8 │    9.5 │   10.3 │  11.3 │  14.9 │ ▂█▆▃▁  │  │
# │ │        quality        │  0 │    0 │   5.818 │   0.8733 │      3 │      5 │      6 │     6 │     9 │  ▁▆█▃▁ │  │
# │ └───────────────────────┴────┴──────┴─────────┴──────────┴────────┴────────┴────────┴───────┴───────┴────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓  │
# │ ┃ column       ┃ NA ┃ NA % ┃ shortest ┃ longest ┃ min  ┃ max   ┃ chars per row ┃ words per row ┃ total words ┃  │
# │ ┡━━━━━━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩  │
# │ │     type     │  0 │    0 │   Red    │  White  │ Red  │ White │          4.51 │             1 │        6497 │  │
# │ │ quality_ind  │  0 │    0 │   Low    │  High   │ High │  Low  │           3.2 │             1 │        6497 │  │
# │ └──────────────┴────┴──────┴──────────┴─────────┴──────┴───────┴───────────────┴───────────────┴─────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# ## Explore the following datasets using skim library
# * df_iris
#
# * df_contact_lenses
#
# * df_titanic
#
# * df_airbnb
#
# * df_diabetes
#
# * df_heart
#
# * df_students
#
# * df_occupancy

# %%
skim(df_iris)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 151    │ │ string      │ 5     │                                                          │
# │ │ Number of columns │ 5      │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━┳━━━━━┳━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━┳━━━━━┳━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓  │
# │ ┃ column       ┃ NA  ┃ NA %  ┃ shortest ┃ longest ┃ min ┃ max  ┃ chars per row ┃ words per row ┃ total words ┃  │
# │ ┡━━━━━━━━━━━━━━╇━━━━━╇━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━╇━━━━━╇━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩  │
# │ │ SepalLength  │   0 │     0 │    0     │  Type   │  0  │ Type │          1.02 │             1 │         151 │  │
# │ │  SepalWidth  │   0 │     0 │    2     │   PW    │  1  │  PW  │          1.67 │             1 │         151 │  │
# │ │ PetalLength  │   0 │     0 │    PL    │   PL    │ 10  │  PL  │             2 │             1 │         151 │  │
# │ │  PetalWidth  │   0 │     0 │    SW    │   SW    │ 20  │  SW  │             2 │             1 │         151 │  │
# │ │   Species    │   0 │     0 │    SL    │   SL    │ 43  │  SL  │             2 │             1 │         151 │  │
# │ └──────────────┴─────┴───────┴──────────┴─────────┴─────┴──────┴───────────────┴───────────────┴─────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
skim(df_airbnb)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ Dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 50098  │ │ string      │ 3     │                                                          │
# │ │ Number of columns │ 5      │ │ int64       │ 1     │                                                          │
# │ └───────────────────┴────────┘ │ float64     │ 1     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┓  │
# │ ┃ column         ┃ NA   ┃ NA %    ┃ mean     ┃ sd       ┃ p0   ┃ p25    ┃ p50   ┃ p75   ┃ p100    ┃ hist     ┃  │
# │ ┡━━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━┩  │
# │ │   DATE_DIFF    │    0 │       0 │     51.5 │    93.07 │    0 │      1 │     4 │    48 │     365 │    █▁    │  │
# │ │      AGE       │    0 │       0 │    48.35 │    152.5 │    2 │     28 │    33 │    41 │    2014 │    █     │  │
# │ └────────────────┴──────┴─────────┴──────────┴──────────┴──────┴────────┴───────┴───────┴─────────┴──────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━┳━━━━┳━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━┓  │
# │ ┃         ┃    ┃      ┃           ┃            ┃           ┃            ┃ chars per ┃ words per  ┃ total     ┃  │
# │ ┃ column  ┃ NA ┃ NA % ┃ shortest  ┃ longest    ┃ min       ┃ max        ┃ row       ┃ row        ┃ words     ┃  │
# │ ┡━━━━━━━━━╇━━━━╇━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━┩  │
# │ │   ID    │  0 │    0 │ lsw9q7uk0 │ lsw9q7uk0j │ 000wc9mlv │ zzyq03wcsh │        10 │          1 │     50098 │  │
# │ │         │    │      │     j     │            │     3     │            │           │            │           │  │
# │ │ GENDER  │  0 │    0 │   MALE    │   FEMALE   │  FEMALE   │    MALE    │      5.08 │          1 │     50098 │  │
# │ │ COUNTRY │  0 │    0 │    US     │     US     │    AU     │     US     │         2 │          1 │     50098 │  │
# │ └─────────┴────┴──────┴───────────┴────────────┴───────────┴────────────┴───────────┴────────────┴───────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %% [markdown]
# # Statistical Data Types / "Levels" of Measurement
# Steven's levels of measure consist of:
# *   Nominal / Categorical
# *   Ordinal
# *   Interval
# *   Ratio
#
# Each "level" of measure allows us to apply more arithmetic operators on the data. It also allows us to better understand what the data actually represents and how it can be manipulated appropriately.
#
# For example, treating  "Eye colour" as a **nominal** variable would allow us to check whether two or more eye colours are equal.
# Brown = Hazel?
# Hazel != Blue?
#
# But we should not be able to make statements such as:
# Brown > Hazel
# Blue > Brown
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Qualitative: Nominal
# Nominal variables (also referred to as categorical variables) are variables that specify a set of values with no intrinsic order.
# Examples of nominal variables could be gender, country, species, and so on.
#
# We can plot nominal variables using a [countplot](https://seaborn.pydata.org/generated/seaborn.countplot.html) which is a type of plot that can be thought of as an alternative to a [histogram](https://simple.wikipedia.org/wiki/Histogram) for categorical variables

# %%
df_iris["Species"].head()
# Out:
# 0    SL
# 1    50
# 2    67
# 3    69
# 4    46
# Name: Species, dtype: str

# %%
sns.countplot(x ='Species', data=df_iris);

# %%
sns.countplot(x = 'COUNTRY', data= df_airbnb);

# %% [markdown]
# A special subtype of nominal variable levels are "dichotomous variables", these are variables that only have two possible value.

# %%
df_contact_lenses["astigmatism"].head()
# Out:
# 0     no
# 1     no
# 2    yes
# 3    yes
# 4     no
# Name: astigmatism, dtype: str

# %%
sns.countplot(x = 'astigmatism', data = df_contact_lenses)
# Out:
# <Axes: xlabel='astigmatism', ylabel='count'>

# %%
sns.countplot(x = 'survived', data = df_titanic)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %% [markdown]
# ## Qualitative / Quantitative: Ordinal
# Ordinal variables contain values that have an inherent **ordering** (e.g. from smallest to largest or from largest to smallest). Each of the values within ordinal variables can be "spaced" unequally, this means that the actual difference between each level is not constant.
#
# For example, say a restaurant provides three sizes of drinks:
# 1.   Small
#   * 300ml
# 2.   Medium
#   * 500ml
# 3.   Large
#   * 750ml
#
# The amount of drink provided in each of the level values is not a constant, the relative difference between **medium** and **large** is greater than the relative difference between **small** and **medium**

# %%
sns.countplot(x = 'pclass', data = df_titanic)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %% [markdown]
# We can also provide a specific order when countplotting ordinal values that aren't encoded numerically. For examples with levels of education (in the US), we might specify the following order:
#
#
# 1.   Some high school
# 2.   High school
# 3.   Some College
# 4.   Associate's degree
# 5.   Bachelor's degree
# 6.   Master's degree

# %%
# We'll specify a particular figure size for the plot, so it doesn't get
# bunched up
plt.figure(figsize=(10,5))
sns.countplot(x= 'parental level of education', data = df_students,
              order=['some high school', 'high school',
                     'some college',  "associate's degree",
                     "bachelor's degree", "master's degree" ])
# Out:
# <Axes: xlabel='parental level of education', ylabel='count'>

# %% [markdown]
# ## Quantitative: Interval
#
# Interval variables exist for data which is continuous in nature and has a numerical
# value. Take, for example, the daily temperature of a room measured at a particular time (e.g. midday).
# Differences between intervals are constant, this means that the difference between 5 Celsius and 2 Celsius is the same as the difference between 10 Celsius and 7 Celsius. We can work out the **mean** and **median** averages of interval variables. However, it is important to note that intervals don’t have a
# **"true zero point"**.

# %% [markdown]
# ### True Zero Point
#
# If a level of measurement has a "true zero point", then that means that a value of 0 represents that you have nothing of that item of interest. Let's take, for example, a variable which represents the number of drinks bought, a
# value of 0 will signify that **no drinks were bought**. The "true zero point" is the main way we can discriminate between between quantiative variables to decide whether they are interval or ratio values.

# %% [markdown]
# Temperature in celsius or fahrenheit is measured on an **interval scale** this is because a temperature of 0 celsius is not a True Zero Point. So to look at our  [occupancy dataset](https://moodle.bcu.ac.uk/mod/resource/view.php?id=8096164) we can see that Temperature should be an interval variable.

# %%
sns.histplot(x ='Temperature', data = df_occupancy)
# Out:
# <Axes: xlabel='Temperature', ylabel='Count'>

# %% [markdown]
# ## Quantitative: Ratio
#
# The most obvious difference between interval and ratio variables are that ratio variables have a **"true zero point"**
#
# Let's compare temperature (in Celsius), with say distance (in Metres) travelled on foot.
#
# 0 Celsius does not indicate the **"absence of temperature"** - if it did we would not be able to have valid negative temperatures in Celsius
#
# 0 Metres in this case however would indicate an **absence of travelling any distance by foot**
#
# While temperature measured in Celsius or Fahrenheit are both on the Interval scale due to the lack of a **true zero point** the [Kelvin](https://en.wikipedia.org/wiki/Kelvin) temperature scale is measured on a Ratio scale as it has a **true zero point** in Physics this **true zero point** for temperature is referred to as **[Absolute zero](https://simple.wikipedia.org/wiki/Absolute_zero)**

# %%
sns.histplot(x='age', data=df_titanic)
# sns.histplot(x = 'Age', data = df, kde=True) # 'kde': kernel density estimate
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(x = 'MaxHR', data = df_heart)
# Out:
# <Axes: xlabel='MaxHR', ylabel='Count'>

# %% [markdown]
# # Data Distributions
#
# One of the best ways to describe a given variable / attribute in a dataset is to report the values that appear within the dataset for that variable / attribute, along with the amount of times each value appears.
#
# We call this way of describing the variable / attribute the "distribution" of that variable / attribute.

# %% [markdown]
# ## Histograms

# %% [markdown]
#  The most common visual representation of a distribution is a "histogram", which is a chart
# that shows the frequency ("count") of each value for that given variable / attribute.

# %%
sns.histplot(x = 'SepalLength', data = df_iris);

# %%
# We can also write the above as:
sns.histplot(df_iris, x="SepalLength")
# Out:
# <Axes: xlabel='SepalLength', ylabel='Count'>

# %%
sns.histplot(df_iris["SepalWidth"])
# Out:
# <Axes: xlabel='SepalWidth', ylabel='Count'>

# %%
sns.histplot(df_iris["PetalLength"])
# Out:
# <Axes: xlabel='PetalLength', ylabel='Count'>

# %%
sns.histplot(df_iris["PetalWidth"])
# Out:
# <Axes: xlabel='PetalWidth', ylabel='Count'>

# %% [markdown]
# Histograms that deal with a large range of values can also place data from preset ranges into "bins", this is very useful when we have quite a wide range of values. Let's take Passenger 'Age' on the Titanic dataset, we could try to have a count for each individual age value:
#
#
# *   17
# *   18
# *   19
# *   etc.
#
# Or we could combine values into smaller "sub-ranges" or "bins". For example, going up in 5s we could have the following:
#
# *   0-4
# *   4-9
# *   10-14
# *   15-19
# *   20-24
# *   etc.
#
# If we went up in 10s, we could have the following
#
# * 0-9
# * 10-19
# * 20-29
# * etc

# %%
sns.histplot(df_titanic["age"])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# The bins argument in this case
# specifies the desired amount of bins,
# not their size!
sns.histplot(df_titanic["age"], bins=10)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ## Boxplot
#
# Boxplots (sometimes called "Box and whisker plots" are a standard means of displaying the distribution of data based on a summary consisting of five major points:
# * The "minimum" **expected** value, this is not necessarily the smallest value one might find for that variable / attribute
# * The first quartile (sometimes called Q1)
# * The median
# * The third quartile (sometimes called Q3)
# * The "maximum" **expected** value, this is not necessarily the largest value one might find for that variable / attribute
#
# "Quartiles" in this case being specific [percentile](https://simple.wikipedia.org/wiki/Percentile) values that are commonly of interest when analysing data. With the 25th, 50th and 75th percentiles being designated as first quartile (Q1), second quartile (median) and third quartile (Q3) respectively.
#
# If you are interested in looking into why the "minimum" and "maximum" expected values are not necessarily the same as the true smallest values in the dataset check out the following article [here](https://builtin.com/data-science/boxplot)

# %%
sns.boxplot(df_iris["SepalLength"]) # orient = 'h'
# Out:
# <Axes: ylabel='SepalLength'>

# %%
df_iris["SepalLength"].describe()
# Out:
# count     151
# unique      4
# top         0
# freq       50
# Name: SepalLength, dtype: object

# %% [markdown]
# We can see for the Iris dataset's SepalLength attribute:
#
#
# *   Q1 (the 25th percentile) is about 5.1 cm
#   * 25% of all SepalLengths are less than or equal to 5.1cm
# *   Q2 (the median and 50th percentile) is about 5.8 cm
#   * 50% of all SepalLengths are less than or equal to 5.8cm
# *   Q3 (the 75th percentile) is about 6.5 cm
#   * 75% of all SepalLengths are less than or equal to 6.5cm

# %%
sns.boxplot(df_iris["SepalWidth"])
df_iris["SepalWidth"].describe()
# Out:
# count     151
# unique     23
# top         2
# freq       29
# Name: SepalWidth, dtype: object

# %% [markdown]
# Now things have gotten even more interesting!
# The little shapes that we have outside of our boxplots "whiskers" represent "Outliers". These are because they are outside the "minimum" and "maximum" expected range of values for the data.

# %%
sns.boxplot(df_iris["PetalLength"])
# Out:
# <Axes: ylabel='PetalLength'>

# %%
sns.boxplot(df_iris["PetalWidth"])
# Out:
# <Axes: ylabel='PetalWidth'>

# %% [markdown]
# ## The "Normal" distribution

# %% [markdown]
# The [normal distribution](https://simple.wikipedia.org/wiki/Normal_distribution), sometimes called the “Bell-curve” or the “Gaussian distribution” based on its discovery by Carl Friedrich Gauss is possibly the most well known of all the distributions of data. While we tend to refer to “the” Normal distribution the fact is that it is actually a family of distributions that have roughly the same shape, each of these individual distributions may have a different size/scale and location. With the standard deviation defining the scale of the distribution whereas the mean defines its location.

# %% [markdown]
# # Measures of central tendency and data dispersion

# %% [markdown]
# ## Measures of central tendency
# Mean, Median, Mode

# %% [markdown]
# ### Mean
# The [mean average](https://simple.wikipedia.org/wiki/Mean) is one of the simplest and most common measures used in data analysis. The simplest form of the mean average is the arithmetic mean which is the result of summing all the values of a given variable / attribute together then dividing that by the amount of values.

# %% [markdown]
# ### Median
# The [median average](https://simple.wikipedia.org/wiki/Median) is another simple and common measure used in data analysis. The median can be calculated first by sorting the values from smallest to largest, with an odd amount of values the median can be found at index (n+1) / 2 where n is the amount of values. If there is an even amount of values the median is the mean average of the two elements in the "centre" of the sorted sequence.

# %% [markdown]
# ### Mode
# The modal average is another simple and common measure used in data analysis. The mode is simply the most common value for a given variable / attribute.

# %%
plt.figure(figsize=(10,5))
sns.countplot(df_students, x ='parental level of education')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1297457974.py in <cell line: 0>()
#       1 plt.figure(figsize=(10,5))
# ----> 2 sns.countplot(df_students, x ='parental level of education')
#
# NameError: name 'df_students' is not defined

# %%
df_students['parental level of education'].mode()
# Out:
# 0    some college
# Name: parental level of education, dtype: object

# %% [markdown]
# ## Measures of dispersion
# Range, IQR, Variance, Standard Deviation

# %% [markdown]
# ### Range
# Range is the difference between the smallest value of a given variable / attribute and the largest.

# %% [markdown]
# ### Standard Deviation
#
# The [Standard deviation](https://simple.wikipedia.org/wiki/Standard_deviation) is a measure of data dispersion that allows us to see how individual values are spread out from the mean average. The higher the standard deviation the more that the values are spread out from the mean, while the smaller the standard deviation the more values are found close to the mean.

# %%
df_iris['PetalLength'].std()
# Out:
# 1.7644204199522626

# %% [markdown]
# # Skewness

# %% [markdown]
# [Skewness](https://www.analyticsvidhya.com/blog/2020/07/what-is-skewness-statistics/) is a measure of how symmetric (or asymetric) a given distribution is. We can divide skewness into three general groups, positive skewed, symmetric and negative skewed.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Positive skew (Right skew)

# %% [markdown]
# **skewnorm** takes a real number
#  as a skewness parameter When a = 0 the distribution is identical to a normal distribution (norm)

# %%
a=150
data= skewnorm.rvs(a, size=1000, scale=10)
sns.histplot(data)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df_titanic["age"], bins=10)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.Series.skew.html
df_titanic["age"].skew()
# Out:
# np.float64(0.4076718864978293)

# %% [markdown]
# ### Negative skew (Left skew)

# %%
df_heart['MaxHR'].skew()
# Out:
# -0.5374486699106463

# %%
sns.histplot(df_heart['MaxHR'])
# Out:
# <Axes: xlabel='MaxHR', ylabel='Count'>

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Question: Datasets
# Why might it be more appropriate to plot the distribution of Species for the iris dataset (along with similar variables like it) with a countplot rather than a histogram?

# %% [markdown]
# ### Sample answer
#
# * A count plot is more appropriate for this data set than a histogram as the result is categorical. The result data is separated into classes. A histogram is more appropriate for continuous data, where we need to check the spread of values for a given attribute.
#
# *   The level of measure for 'Species' is nominal therefore we are not plotting the distribution of a quantitative variable but instead looking for the relative counts of each category, thus making a countplot the more appropriate choice
#
# * A count plot is more appropriate for this data set than a histogram as the result is categorical. The result data is separated into classes. A histogram is more appropriate for continuous data, where we need to check the spread of values for a given attribute.

# %%
sns.countplot(df_iris , x = "Species")
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %% [markdown]
# ## Question: Datasets
#
# Choose at least 3 variables which we have not yet visualised from each of the datasets we have used in this lab. Where appropriate create relevant countplots, histograms and boxplots using Python's seaborn library

# %% [markdown]
# #### Data Set 1 - Heart

# %%
df_heart = pd.read_csv('Heart.csv')
df_heart.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
sns.histplot(df_heart["RestBP"], bins=10)
# Out:
# <Axes: xlabel='RestBP', ylabel='Count'>

# %%
df_heart["RestBP"].skew()
# Out:
# 0.7060346498131783

# %%
sns.boxplot(df_heart["Chol"])
df_heart["Chol"].describe()
# Out:
# count    303.000000
# mean     246.693069
# std       51.776918
# min      126.000000
# 25%      211.000000
# 50%      241.000000
# 75%      275.000000
# max      564.000000
# Name: Chol, dtype: float64

# %%
df_heart["Chol"].skew()
# Out:
# 1.1355031533363453

# %%
sns.countplot(df_heart, x ="ChestPain")
# Out:
# <Axes: xlabel='ChestPain', ylabel='count'>

# %% [markdown]
# #### Data Set 2 - Students

# %%
df_students = pd.read_csv('StudentsPerformance.csv')
df_students.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.histplot(df_students["math score"], bins=12)
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
df_students["math score"].skew()
# Out:
# -0.27893514909431694

# %%
sns.boxplot(df_students["reading score"])
df_students["reading score"].describe()
# Out:
# count    1000.000000
# mean       69.169000
# std        14.600192
# min        17.000000
# 25%        59.000000
# 50%        70.000000
# 75%        79.000000
# max       100.000000
# Name: reading score, dtype: float64

# %%
sns.countplot(df_students, x = "race/ethnicity")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='count'>

# %% [markdown]
# #### Data Set 3 - Indians Diabetes

# %%
df_diabetes = pd.read_csv('indians-diabetes.csv',
                          names=['Pregnancies','Glucose','BloodPressure',
                                 'SkinThickness','Insulin','BMI',
                                 'DiabetesPedigreeFunction','Age','Outcome'])
df_diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
sns.histplot(df_diabetes["Age"], bins=12)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df_diabetes["Age"].skew()
# Out:
# 1.1295967011444805

# %%
sns.boxplot(df_diabetes["Age"])
df_diabetes["Age"].describe()
# Out:
# count    768.000000
# mean      33.240885
# std       11.760232
# min       21.000000
# 25%       24.000000
# 50%       29.000000
# 75%       41.000000
# max       81.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(df_diabetes["BMI"])
df_diabetes["BMI"].describe()
# Out:
# count    768.000000
# mean      31.992578
# std        7.884160
# min        0.000000
# 25%       27.300000
# 50%       32.000000
# 75%       36.600000
# max       67.100000
# Name: BMI, dtype: float64

# %%
sns.countplot(df_diabetes, x ="Pregnancies")
# Out:
# <Axes: xlabel='Pregnancies', ylabel='count'>

# %%
sns.countplot(df_diabetes, x = "Outcome")
# Out:
# <Axes: xlabel='Outcome', ylabel='count'>

# %% [markdown]
# # Exercise 3
# ## Question: Datasets
# On the [UCI Machine Learning repository](https://archive.ics.uci.edu/ml/datasets.php) identify two datasets with 1000 or less instances (records) that are relevant for a classification task and identify an additional two datasets with 1000 or less instances (records) that are relevant to a regression task.
#
# How could these datasets be loaded into your notebook via Pandas? Show some example code to create your dataframes.

# %% [markdown]
# ### Sample Answer

# %% [markdown]
# #### Classification Set 1 - Breast Cancer
# ###### https://archive.ics.uci.edu/ml/datasets/Breast+Cancer

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer/breast-cancer.data", header=None, names=["Class", "age", "menopause", "tumor-size", "inv-nodes", "node-caps", "deg-malig", "breast", "breast-quad", "irradiat"])
df.head()
# Out:
#                   Class    age menopause tumor-size inv-nodes node-caps  \
# 0  no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2  no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3  no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4  no-recurrence-events  40-49   premeno        0-4       0-2        no
#
#    deg-malig breast breast-quad irradiat
# 0          3   left    left_low       no
# 1          2  right    right_up       no
# 2          2   left    left_low       no
# 3          2  right     left_up       no
# 4          2  right   right_low       no

# %% [markdown]
# #### Classification Set 2 - HCV
# ###### https://archive.ics.uci.edu/ml/datasets/HCV+data

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00571/hcvdat0.csv")
df = df.drop(["Unnamed: 0"], axis=1)
df.head()
# Out:
#         Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  CHOL   CREA  \
# 0  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93  3.23  106.0
# 1  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17  4.80   74.0
# 2  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84  5.20   86.0
# 3  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33  4.74   80.0
# 4  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15  4.32   76.0
#
#     GGT  PROT
# 0  12.1  69.0
# 1  15.6  76.5
# 2  33.2  79.3
# 3  33.8  75.7
# 4  29.9  68.7

# %% [markdown]
# #### Regression Set 1 - Auto MPG
# ###### https://archive.ics.uci.edu/ml/datasets/Auto+MPG

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data", sep="\s+", header=None, names=["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model year", "origin", "car name"])
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### Regression Set 2 - Real Estate Valuation
# ###### https://archive.ics.uci.edu/ml/datasets/Real+estate+valuation+data+set

# %%
df = pd.read_excel("https://archive.ics.uci.edu/ml/machine-learning-databases/00477/Real%20estate%20valuation%20data%20set.xlsx")
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1          2012.916667          32.0
# 1   2          2012.916667          19.5
# 2   3          2013.583333          13.3
# 3   4          2013.500000          13.3
# 4   5          2012.833333           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %% [markdown]
# # Exercise 4
# ## Question: Levels of measure
# **Differentiating between levels of measure**
#
# Which of the following temperature scale measures are interval and which are ratio, explain your answer
# *   Celsius
# *   Fahrenheit
# *   Kelvin

# %% [markdown]
# ### Sample answer
#
# <details><summary>Click here for the solution</summary>
# * Celcius and farenheit are both interval measures, as they allow values that are below 0. The scale used denotes a defined '0' value, and values for other measures are relative to this value.
#
# * Kelvin is an example of a ratio measure, as it has a true 0 value which the temperature cannot dip below.
#
# * Celsius and Fahrenheit are both interval because they do not have a "true zero point" indicating a lack of temperature, whereas the 0 point on the Kelvin scale indicates an "absolute zero"
#
# * Celcius and farenheit are both interval measures, as they allow values that are below 0. The scale used denotes a defined '0' value, and values for other measures are relative to this value.
#
# * Kelvin is an example of a ratio measure, as it has a true 0 value which the temperature cannot dip below.
#
# </details>

# %% [markdown]
# # Exercise 5
# ## Question: Levels of measure
# **Choosing an appropriate statistical data type / level of measure**
#
# What could be an appropriate statistical data type / level of measure choice for the following attributes? Explain your choice of type (nominal/categorical, ordinal, interval, ratio)
#
#
# *   quality on the wine data set (df_wine)
# *   quality_ind on the wine data set (df_wine)
# *   alcohol on the wine data set (df_wine)
# *   Fare on the titanic data set (df_titanic)
# *   Survived on the titanic data set (df_titanic)

# %% [markdown]
# ### Sample Answer

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# #### quality on the wine data set (df_wine):
# This series contains ordinal data. The values are defined and can be considered as 'categories', but they also follow an order.
#
# #### quality_ind on the wine data set (df_wine):
# This series contains categorical data. Each value is ether 'Low' or 'High', splitting the results into one of two categories.
#
# #### alcohol on the wine data set (df_wine):
# This series contains continuous data, which has a defined '0' point, and therefore a ratio type is most appropriate.
#
# #### Fare on the titanic data set (df_titanic):
# This series contains continuous data, which has a defined '0' point, and therefore a ratio type is most appropriate.
#
# #### Survived on the titanic data set (df_titanic):
# This series contains data with either a value of 0, or a value of 1. Therefore, the data is categorical, as each record has one of two possible values.
#
# </details>

# %% [markdown]
# # Exercise 6
# ## Question: Levels of measure
# **Nominal vs Ordinal**
#
# How is a nominal / categorical scale different to an ordinal scale? What impact does this have on what analysis / processing can be performed on the data?

# %% [markdown]
# ### Sample answer
#
# <details><summary>Click here for the solution</summary>
#
# Nominal/categorical data is data which is labelled in some way. This data has no natural ordering, and as such, no result can be considered to be 'better', or 'greater' than another. Such comparisons are not possible.
#
# Ordinal data, on the other hand, does have a natural order. It's possible to make comparisons such as > or < between records as a result. It's also feasible to plot such data using a chart such as a histogram, which would not be suitable for nomical/categorical data.
#
# Nominal/categorical data is data which is labelled in some way. This data has no natural ordering, and as such, no result can be considered to be 'better', or 'greater' than another. Such comparisons are not possible.
#
# Ordinal data, on the other hand, does have a natural order. It's possible to make comparisons such as > or < between records as a result. It's also feasible to plot such data using a chart such as a histogram, which would not be suitable for nomical/categorical data.
# A nominal scale variable suggests that the attribute of interest is only differentiable from others based on its name / category whereas an ordinal scale variable implies the presence of a rank or order between the values.
#
# An example of some nominal variables could be:
# *   Gender {Male, Female, }
# *   Nationality {British, American, Irish, Indian, Pakistani, ...}
# *   Religion {Christian, Muslim, Jewish, Hindu, Sikh, Buddhist, Non-Religious, Other}
# *   UK Domicile status {Domiciled, Non-Domiciled}
#
# An example of some ordinal variables could be:
#
# *   Drink sizes {Small, Medium, Large}
# *   Degree classification {1st, 2-1, 2-2, 3rd, Fail}
#
#
#
#
# </details>

# %% [markdown]
# # Exercise 7
# ## Question: Levels of measure
# **Interval vs Ratio**
#
# How is an interval scale different to a ratio scale? What impact would this have on what analysis / processing can be performed on the data?

# %% [markdown]
# ### Sample answer
# <details><summary>Click here for the solution</summary>
# Students would be expected to discuss the need for a **true zero point** with ratio scale data and compare this with interval scale values which do not require a **true zero point**
#
#
#
# A ratio scale has a 'true' value of 0, which is the lowest possible value. An interval scale can have negative values, and an arbitrary 0 value. This impacts the scale that is relevent for each data set.
#
# </details>

# %% [markdown]
# # Exercise 8
# ## Question: Levels of measure
# What is an appropriate "level of measure" for the Sepal Width in the Iris data set? Explain your answer.

# %% [markdown]
# ### Sample answer
#
# <details><summary>Click here for the solution</summary>
# Students would be expected to discuss the fact that Sepal Width in cm would have a **true zero point** and therefore would be best treated as ratio scale data
#
# Ratio is an appropriate level of measure for sepal width, as it has a defined '0' value and is a continuous data set.
#
# A ratio scale has a 'true' value of 0, which is the lowest possible value. An interval scale can have negative values, and an arbitrary 0 value. This impacts the scale that is relevent for each data set.
#
# </details>

# %% [markdown]
# # Exercise 9
# ## Question: Levels of measure
#
# What is an appropriate level of measure for the "MaxHR" maximum heart-rate in the Heart dataset? Explain your answer

# %% [markdown]
# ### Sample answer
#
#
# <details><summary>Click here for the solution</summary>
# Again, Students would be expected to discuss the fact that Maximum heart-rate would have a **true zero point** and therefore would be best treated as ratio scale data
#
# For maximum heart rate, a ratio level of measure is appropriate as all values have a true 0 value, and the relationship between values are relative to the 0 value.
#
# </details>

# %% [markdown]
# # Exercise 10
# ## Question: Levels of measure
#
# What are the appropriate levels of measure for each variable / attribute in your group's chosen dataset? Explain your answer

# %% [markdown]
# ### Sample answer
# <details><summary>Click here for the solution</summary>
#
# #### Coursework data set required
# </details>

# %% [markdown]
# # Exercise 11
# ## Question: Data Distributions
# By creating a box and whisker plot of AirBNB's AGE variable / attribute, what can this tell us about the data?

# %% [markdown]
# ### Sample Answer

# %% [markdown]
# There are outliers well outside the expected range of a user's age. Possibly suggesting that we have some issues with data quality.
#
# <details><summary>Click here for the solution</summary>
#
# ```python
# df_airbnb = pd.read_csv('/content/drive/MyDrive/CMP7161/datasets/airbnb.csv')
# plt.figure(figsize=(30,10))
# sns.boxplot(df_airbnb["AGE"],  orient="h")
# df_airbnb
#
# ```
#
# </details>
#
# This data contains a huge amount of outliers, some of which are very extreme. We can see that the data is 'unclean' and likely to contain errors to give such extreme values.

# %% [markdown]
# # Exercise 12
# ## Question: Measures of central tendency and data dispersion
# Why might it be innappropriate to try to find the mean or median value of the following attributes? Attempt to generate the mean and median values for each and use this to explain your answer.
# *   Species on the Iris data-set
# *   Survived on the titanic data set
# *   Pclass on the titanic data set

# %% [markdown]
# ### Sample Answer

# %%
# Due to the string encoding of 'Species' on the iris data set from iris.data,
# mean and median calculations will result in type errors within Python.
# Mode would be a far more useful measure here.
# sns.countplot(df_iris['Species'])
# df_iris['Species'].mean() = Type error
# df_iris['Species'].median() = Type error
# df_iris['Species'].mode()

# While Pclass is encoded numerically on titanic,
# despite being a categorical (or possibly even ordinal) variable
# this means that Pandas will think that mean and median are valid operations
# that could be performed on the data
# However, such measures of central tendency does not make sense with this kind of attribute
# mode would be a far more useful measure here
#sns.countplot(df_titanic['Pclass'])
# df_titanic['Pclass'].mean() = 2.308641975308642
# df_titanic['Pclass'].median() = 3.0
# df_titanic['Pclass'].mode()  = 3

# Survived is a nominal / categorical variable (technically dichotomous)
# However it is encoded numerically within the Data Frame
# this means that Pandas will think that mean and median are valid operations
# that could be performed on the data
# sns.countplot(df_titanic['Survived'])
# df_titanic['Survived'].mean() # = 0.3838383838383838
# df_titanic['Survived'].median() = 0.0
# df_titanic['Survived'].mode() = 0

# %%
df_iris = pd.read_csv('iris.data',
                        names=['SepalLength','SepalWidth','PetalLength','PetalWidth','Species'])

# %%
#  df_iris["Species"].mean()

# %%
# df_iris["Species"].median()

# %% [markdown]
# Mode is not suitable for the "Species" attribute as the data is categorical/nominal. There's no connection between the values, and it's not possible to find an average as a result. In this case, the data is also formed of strings.
#
# Median is not suitable for this attribute as no value is returned. Median requires numerical data, and this data is formed of strings. An error is returned when trying to calculate the median for this reason. It's not possible to find a midpoint between to strings (if required).

# %% [markdown]
# #### Survived on the Titanic Data Set

# %%
df_titanic = pd.read_csv('titanic.csv')
df_titanic["Survived"].mean()
# Out:
# 0.3838383838383838

# %%
df_titanic["Survived"].median()
# Out:
# 0.0

# %% [markdown]
# In this case, mode is not suitable as the data is categorical/nominal. It's possible to calculate a result due to the data being numeric, but it has no meaning as it falls between the two possible categories. At best, it simply shows which of the two values is more common.
#
# When using categorical data, the median is inappropriate as it is essentially meaningless. With only two possible outcomes, in this case the value will match the mean.

# %% [markdown]
# #### Pclass on the Titanic Data Set

# %%
df_titanic["Pclass"].mean()
# Out:
# 2.308641975308642

# %%
df_titanic["Pclass"].median()
# Out:
# 3.0

# %% [markdown]
# # Exercise 13
# ## Question: Measures of central tendency and data dispersion
# State which of the following are measures of central tendency and which are measures of data dispersion
#
#
# *   Mean
# *   Standard Deviation
# *   Variance
# *   Mode
# *   Range
# *   Median

# %% [markdown]
# ### Sample Answer
#
# *   Mean = Central tendency
# *   Standard Deviation = Data dispersion
# *   Variance = Data dispersion
# *   Mode = Central tendency
# *   Range = Data dispersion
# *   Median = Central tendency
#
#
# #### Mean
# Mean is a measure of central tendency, as it calculates the average value of the data set.
#
# #### Standard Deviation
# Standard deviation is a measure of the dispersion of the data, as it calculates the average deviation between results across the data set. A higher value signifies greater dispersion.
#
# #### Variance
# Variance is a measure of the square of each deviation in the data set. It is closely linked to standard deviation, which is the square root of the variance. This is another measure of dispersion, as a greater result indicates a wider spread of values.
#
# #### Mode
# Mode is a measure of central tendency, as it returns the most common value. This will create a 'peak' in the data set in a distribution graph.
#
# #### Range
# Range is a measure of data dispersion, as it denotes the maximum and minimum values. A wider range is indicative of a greater degree of data dispersion.
#
# #### Median
# Media is a measure of central tendency, as it returns the middle value in the data set.

# %% [markdown]
# # Exercise 14
# ## Question: Measures of central tendency and data dispersion
# When comparing the average earnings of citizens in various countries, what benefits would comparing median incomes have over comparing mean incomes?

# %% [markdown]
# ## Sample Answer

# %% [markdown]
# When comparing the mean, a few very large values will create a positive skew in the data set, and raise the mean value. The median will see a much smaller impact from these few large values, and give a value which is more representative of the dataset.

# %% [markdown]
# ## Question: Measures of central tendency and data dispersion
# Consider how you would calculate appropriate measures of central tendency and data dispersion for the attribute's in your group's dataset.
#
# For each attribute / variable:
# *   What measures of central tendency could you use?
#   * What would be the appropriate code to calculate these?
# *   What measures of data dispersion could you use?
#   * What would be the appropriate code to calculate these?
